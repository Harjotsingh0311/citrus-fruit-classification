# %% [markdown]
# ## E2 - architecture ablation
#
# Toggles the depthwise-separable conv (block2) and the dilated conv (block3) on/off against a standard 3x3 conv, Adam held fixed since E1 already settled that. `full_citrusnet` (both toggles True) is the existing baseline, not retrained.
#
# Re-run of the three fresh variants against the corrected `citrus_model.py` (the earlier init_weights used here was wrong) - CSVs and checkpoints below get overwritten.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import pandas as pd
import matplotlib.pyplot as plt

from citrus_model import CitrusNetArchAblation, init_weights
from citrus_common import load_normalization_stats, get_transforms, CitrusLeafDataset
from citrus_train import set_seed, fit

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### Data

# %%
set_seed(42)

mean, std = load_normalization_stats()

train_transform = get_transforms(augment=True, mean=mean, std=std, size=224)
val_transform = get_transforms(augment=False, mean=mean, std=std, size=224)

train_dataset = CitrusLeafDataset(root_dir="processed/224", split="train", transform=train_transform)
val_dataset = CitrusLeafDataset(root_dir="processed/224", split="val", transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=0)

len(train_dataset), len(val_dataset)
# Out:
# (1131, 242)

# %% [markdown]
# ### Loss and variant configs
#
# Adam (lr=1e-3, weight_decay=1e-4) for every run - E1 already picked Adam, so it's fixed here while the architecture varies. `full_citrusnet` isn't trained, its history comes from history_baseline.csv.

# %%
class_weights = torch.tensor([0.9921, 0.9240, 1.1880, 0.9363], dtype=torch.float32).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)

variant_configs = {
    "standard_only": dict(use_depthwise_separable=False, use_dilated=False),
    "plus_ds": dict(use_depthwise_separable=True, use_dilated=False),
    "plus_dilated": dict(use_depthwise_separable=False, use_dilated=True),
}

# %% [markdown]
# ### Training runs
#
# Fresh model + init per variant, seed reset right before each build. `init_weights()` is imported as-is from citrus_model.py, not touched here. fit()'s history dict doesn't come back with an explicit epoch column, so one gets inserted before saving to CSV.

# %%
os.makedirs("checkpoints", exist_ok=True)

histories_ordered = {}
param_counts = {}

for name, flags in variant_configs.items():
    set_seed(42)
    model = CitrusNetArchAblation(num_classes=4, **flags)
    init_weights(model)
    model = model.to(device)

    n_params = sum(p.numel() for p in model.parameters())
    param_counts[name] = n_params
    print(f"--- training: {name} (params={n_params}) ---")

    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=3)

    history = fit(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        device=device,
        max_epochs=100,
        early_stop_patience=10,
        scheduler=scheduler,
        checkpoint_path=f"checkpoints/arch_{name}_best.pt",
        verbose=True,
    )

    hist_df = pd.DataFrame(history)
    if "epoch" not in hist_df.columns:
        hist_df.insert(0, "epoch", range(1, len(hist_df) + 1))

    hist_df.to_csv(f"history_arch_{name}.csv", index=False)
    histories_ordered[name] = hist_df
# Out:
# --- training: standard_only (params=432100) ---
# epoch   1  train_loss 0.8491  train_acc 0.6543  val_loss 0.9575  val_acc 0.6736  lr 1.00e-03
# epoch   2  train_loss 0.4839  train_acc 0.8205  val_loss 0.3164  val_acc 0.8884  lr 1.00e-03
# epoch   3  train_loss 0.3386  train_acc 0.8877  val_loss 0.2211  val_acc 0.9132  lr 1.00e-03
# epoch   4  train_loss 0.2870  train_acc 0.9054  val_loss 0.2447  val_acc 0.9256  lr 1.00e-03
# epoch   5  train_loss 0.2497  train_acc 0.9222  val_loss 0.2098  val_acc 0.9050  lr 1.00e-03
# epoch   6  train_loss 0.2023  train_acc 0.9416  val_loss 0.0795  val_acc 0.9587  lr 1.00e-03
# epoch   7  train_loss 0.2160  train_acc 0.9248  val_loss 0.3340  val_acc 0.8347  lr 1.00e-03
# epoch   8  train_loss 0.1868  train_acc 0.9372  val_loss 0.0799  val_acc 0.9793  lr 1.00e-03
# epoch   9  train_loss 0.1828  train_acc 0.9478  val_loss 0.1017  val_acc 0.9545  lr 1.00e-03
# epoch  10  train_loss 0.1948  train_acc 0.9399  val_loss 1.0415  val_acc 0.7521  lr 5.00e-04
# epoch  11  train_loss 0.1584  train_acc 0.9452  val_loss 0.0287  val_acc 1.0000  lr 5.00e-04
# epoch  12  train_loss 0.1107  train_acc 0.9708  val_loss 0.0259  val_acc 0.9959  lr 5.00e-04
# epoch  13  train_loss 0.1116  train_acc 0.9691  val_loss 0.0132  val_acc 1.0000  lr 5.00e-04
# epoch  14  train_loss 0.0752  train_acc 0.9797  val_loss 0.0127  val_acc 1.0000  lr 5.00e-04
# epoch  15  train_loss 0.0873  train_acc 0.9699  val_loss 0.0316  val_acc 0.9793  lr 5.00e-04
# epoch  16  train_loss 0.1189  train_acc 0.9673  val_loss 0.0215  val_acc 0.9959  lr 5.00e-04
# epoch  17  train_loss 0.0789  train_acc 0.9752  val_loss 0.0064  val_acc 1.0000  lr 5.00e-04
# epoch  18  train_loss 0.0575  train_acc 0.9850  val_loss 0.0180  val_acc 0.9876  lr 5.00e-04
# epoch  19  train_loss 0.0738  train_acc 0.9761  val_loss 0.0099  val_acc 1.0000  lr 5.00e-04
# epoch  20  train_loss 0.0853  train_acc 0.9779  val_loss 0.0106  val_acc 1.0000  lr 5.00e-04
# epoch  21  train_loss 0.0698  train_acc 0.9779  val_loss 0.0122  val_acc 1.0000  lr 2.50e-04
# epoch  22  train_loss 0.0545  train_acc 0.9867  val_loss 0.0221  val_acc 0.9876  lr 2.50e-04
# epoch  23  train_loss 0.0419  train_acc 0.9929  val_loss 0.0079  val_acc 1.0000  lr 2.50e-04
# epoch  24  train_loss 0.0356  train_acc 0.9920  val_loss 0.0059  val_acc 1.0000  lr 2.50e-04
# epoch  25  train_loss 0.0491  train_acc 0.9841  val_loss 0.0166  val_acc 0.9959  lr 2.50e-04
# epoch  26  train_loss 0.0610  train_acc 0.9841  val_loss 0.0116  val_acc 0.9959  lr 2.50e-04
# epoch  27  train_loss 0.0398  train_acc 0.9947  val_loss 0.0075  val_acc 1.0000  lr 2.50e-04
# epoch  28  train_loss 0.0473  train_acc 0.9894  val_loss 0.0052  val_acc 1.0000  lr 2.50e-04
# epoch  29  train_loss 0.0474  train_acc 0.9867  val_loss 0.0117  val_acc 0.9959  lr 2.50e-04
# epoch  30  train_loss 0.0486  train_acc 0.9885  val_loss 0.0077  val_acc 1.0000  lr 2.50e-04
# epoch  31  train_loss 0.0417  train_acc 0.9912  val_loss 0.0086  val_acc 1.0000  lr 2.50e-04
# epoch  32  train_loss 0.0379  train_acc 0.9903  val_loss 0.0037  val_acc 1.0000  lr 2.50e-04
# epoch  33  train_loss 0.0411  train_acc 0.9903  val_loss 0.0067  val_acc 1.0000  lr 2.50e-04
# epoch  34  train_loss 0.0622  train_acc 0.9885  val_loss 0.0068  val_acc 1.0000  lr 2.50e-04
# epoch  35  train_loss 0.0303  train_acc 0.9929  val_loss 0.0147  val_acc 1.0000  lr 2.50e-04
# epoch  36  train_loss 0.0488  train_acc 0.9850  val_loss 0.0088  val_acc 1.0000  lr 1.25e-04
# epoch  37  train_loss 0.0418  train_acc 0.9912  val_loss 0.0073  val_acc 1.0000  lr 1.25e-04
# epoch  38  train_loss 0.0290  train_acc 0.9938  val_loss 0.0037  val_acc 1.0000  lr 1.25e-04
# epoch  39  train_loss 0.0260  train_acc 0.9903  val_loss 0.0022  val_acc 1.0000  lr 1.25e-04
# epoch  40  train_loss 0.0289  train_acc 0.9938  val_loss 0.0028  val_acc 1.0000  lr 1.25e-04
# epoch  41  train_loss 0.0304  train_acc 0.9912  val_loss 0.0081  val_acc 1.0000  lr 1.25e-04
# epoch  42  train_loss 0.0322  train_acc 0.9938  val_loss 0.0025  val_acc 1.0000  lr 1.25e-04
# epoch  43  train_loss 0.0232  train_acc 0.9938  val_loss 0.0047  val_acc 1.0000  lr 6.25e-05
# epoch  44  train_loss 0.0304  train_acc 0.9938  val_loss 0.0044  val_acc 1.0000  lr 6.25e-05
# epoch  45  train_loss 0.0344  train_acc 0.9920  val_loss 0.0031  val_acc 1.0000  lr 6.25e-05
# epoch  46  train_loss 0.0343  train_acc 0.9912  val_loss 0.0049  val_acc 1.0000  lr 6.25e-05
# epoch  47  train_loss 0.0329  train_acc 0.9912  val_loss 0.0031  val_acc 1.0000  lr 3.13e-05
# epoch  48  train_loss 0.0227  train_acc 0.9956  val_loss 0.0032  val_acc 1.0000  lr 3.13e-05
# epoch  49  train_loss 0.0283  train_acc 0.9894  val_loss 0.0025  val_acc 1.0000  lr 3.13e-05
# no val_loss improvement for 10 epochs, stopping early at epoch 49
# --- training: plus_ds (params=416036) ---
# epoch   1  train_loss 0.8194  train_acc 0.6729  val_loss 0.4047  val_acc 0.8471  lr 1.00e-03
# epoch   2  train_loss 0.4477  train_acc 0.8444  val_loss 0.6519  val_acc 0.7314  lr 1.00e-03
# epoch   3  train_loss 0.3560  train_acc 0.8691  val_loss 0.1657  val_acc 0.9545  lr 1.00e-03
# epoch   4  train_loss 0.2714  train_acc 0.9222  val_loss 0.0828  val_acc 0.9628  lr 1.00e-03
# epoch   5  train_loss 0.2367  train_acc 0.9204  val_loss 0.2113  val_acc 0.9132  lr 1.00e-03
# epoch   6  train_loss 0.2212  train_acc 0.9284  val_loss 0.2395  val_acc 0.8884  lr 1.00e-03
# epoch   7  train_loss 0.2229  train_acc 0.9266  val_loss 0.0737  val_acc 0.9669  lr 1.00e-03
# epoch   8  train_loss 0.1446  train_acc 0.9531  val_loss 0.0359  val_acc 0.9959  lr 1.00e-03
# epoch   9  train_loss 0.1514  train_acc 0.9646  val_loss 0.0546  val_acc 0.9793  lr 1.00e-03
# epoch  10  train_loss 0.1545  train_acc 0.9531  val_loss 0.0421  val_acc 0.9835  lr 1.00e-03
# epoch  11  train_loss 0.1536  train_acc 0.9496  val_loss 0.0443  val_acc 0.9917  lr 1.00e-03
# epoch  12  train_loss 0.1387  train_acc 0.9620  val_loss 0.0355  val_acc 1.0000  lr 1.00e-03
# epoch  13  train_loss 0.1380  train_acc 0.9593  val_loss 0.1592  val_acc 0.9215  lr 1.00e-03
# epoch  14  train_loss 0.1416  train_acc 0.9531  val_loss 0.0319  val_acc 0.9876  lr 1.00e-03
# epoch  15  train_loss 0.1266  train_acc 0.9637  val_loss 0.0669  val_acc 0.9793  lr 1.00e-03
# epoch  16  train_loss 0.1396  train_acc 0.9593  val_loss 0.0135  val_acc 0.9959  lr 1.00e-03
# epoch  17  train_loss 0.0955  train_acc 0.9744  val_loss 0.0302  val_acc 0.9917  lr 1.00e-03
# epoch  18  train_loss 0.0991  train_acc 0.9752  val_loss 0.0230  val_acc 0.9876  lr 1.00e-03
# epoch  19  train_loss 0.1091  train_acc 0.9717  val_loss 0.0055  val_acc 1.0000  lr 1.00e-03
# epoch  20  train_loss 0.0914  train_acc 0.9691  val_loss 0.0994  val_acc 0.9669  lr 1.00e-03
# epoch  21  train_loss 0.1502  train_acc 0.9540  val_loss 0.0952  val_acc 0.9545  lr 1.00e-03
# epoch  22  train_loss 0.0610  train_acc 0.9841  val_loss 0.0071  val_acc 1.0000  lr 1.00e-03
# epoch  23  train_loss 0.1146  train_acc 0.9673  val_loss 0.0424  val_acc 0.9793  lr 5.00e-04
# epoch  24  train_loss 0.0863  train_acc 0.9805  val_loss 0.0047  val_acc 1.0000  lr 5.00e-04
# epoch  25  train_loss 0.0738  train_acc 0.9770  val_loss 0.0034  val_acc 1.0000  lr 5.00e-04
# epoch  26  train_loss 0.0474  train_acc 0.9850  val_loss 0.0032  val_acc 1.0000  lr 5.00e-04
# epoch  27  train_loss 0.0364  train_acc 0.9885  val_loss 0.0058  val_acc 1.0000  lr 5.00e-04
# epoch  28  train_loss 0.0330  train_acc 0.9920  val_loss 0.0044  val_acc 1.0000  lr 5.00e-04
# epoch  29  train_loss 0.0379  train_acc 0.9903  val_loss 0.0027  val_acc 1.0000  lr 5.00e-04
# epoch  30  train_loss 0.0569  train_acc 0.9797  val_loss 0.0020  val_acc 1.0000  lr 5.00e-04
# epoch  31  train_loss 0.0405  train_acc 0.9912  val_loss 0.0052  val_acc 1.0000  lr 5.00e-04
# epoch  32  train_loss 0.0346  train_acc 0.9876  val_loss 0.0037  val_acc 1.0000  lr 5.00e-04
# epoch  33  train_loss 0.0444  train_acc 0.9876  val_loss 0.0064  val_acc 1.0000  lr 5.00e-04
# epoch  34  train_loss 0.0500  train_acc 0.9859  val_loss 0.0031  val_acc 1.0000  lr 2.50e-04
# epoch  35  train_loss 0.0309  train_acc 0.9920  val_loss 0.0032  val_acc 1.0000  lr 2.50e-04
# epoch  36  train_loss 0.0389  train_acc 0.9867  val_loss 0.0024  val_acc 1.0000  lr 2.50e-04
# epoch  37  train_loss 0.0269  train_acc 0.9929  val_loss 0.0014  val_acc 1.0000  lr 2.50e-04
# epoch  38  train_loss 0.0368  train_acc 0.9912  val_loss 0.0011  val_acc 1.0000  lr 2.50e-04
# epoch  39  train_loss 0.0243  train_acc 0.9956  val_loss 0.0041  val_acc 1.0000  lr 2.50e-04
# epoch  40  train_loss 0.0190  train_acc 0.9947  val_loss 0.0027  val_acc 1.0000  lr 2.50e-04
# epoch  41  train_loss 0.0368  train_acc 0.9903  val_loss 0.0030  val_acc 1.0000  lr 2.50e-04
# epoch  42  train_loss 0.0229  train_acc 0.9956  val_loss 0.0031  val_acc 1.0000  lr 1.25e-04
# epoch  43  train_loss 0.0248  train_acc 0.9938  val_loss 0.0011  val_acc 1.0000  lr 1.25e-04
# epoch  44  train_loss 0.0176  train_acc 0.9982  val_loss 0.0011  val_acc 1.0000  lr 1.25e-04
# epoch  45  train_loss 0.0308  train_acc 0.9912  val_loss 0.0008  val_acc 1.0000  lr 1.25e-04
# epoch  46  train_loss 0.0241  train_acc 0.9929  val_loss 0.0014  val_acc 1.0000  lr 1.25e-04
# epoch  47  train_loss 0.0257  train_acc 0.9920  val_loss 0.0014  val_acc 1.0000  lr 1.25e-04
# epoch  48  train_loss 0.0205  train_acc 0.9973  val_loss 0.0015  val_acc 1.0000  lr 1.25e-04
# epoch  49  train_loss 0.0151  train_acc 0.9956  val_loss 0.0008  val_acc 1.0000  lr 1.25e-04
# epoch  50  train_loss 0.0210  train_acc 0.9929  val_loss 0.0022  val_acc 1.0000  lr 1.25e-04
# epoch  51  train_loss 0.0166  train_acc 0.9973  val_loss 0.0015  val_acc 1.0000  lr 1.25e-04
# epoch  52  train_loss 0.0229  train_acc 0.9929  val_loss 0.0009  val_acc 1.0000  lr 1.25e-04
# epoch  53  train_loss 0.0232  train_acc 0.9947  val_loss 0.0025  val_acc 1.0000  lr 6.25e-05
# epoch  54  train_loss 0.0214  train_acc 0.9929  val_loss 0.0013  val_acc 1.0000  lr 6.25e-05
# epoch  55  train_loss 0.0181  train_acc 0.9973  val_loss 0.0008  val_acc 1.0000  lr 6.25e-05
# epoch  56  train_loss 0.0148  train_acc 0.9956  val_loss 0.0014  val_acc 1.0000  lr 6.25e-05
# epoch  57  train_loss 0.0171  train_acc 0.9956  val_loss 0.0014  val_acc 1.0000  lr 6.25e-05
# epoch  58  train_loss 0.0131  train_acc 0.9982  val_loss 0.0009  val_acc 1.0000  lr 6.25e-05
# epoch  59  train_loss 0.0144  train_acc 0.9982  val_loss 0.0010  val_acc 1.0000  lr 3.13e-05
# epoch  60  train_loss 0.0210  train_acc 0.9956  val_loss 0.0009  val_acc 1.0000  lr 3.13e-05
# epoch  61  train_loss 0.0131  train_acc 0.9965  val_loss 0.0007  val_acc 1.0000  lr 3.13e-05
# epoch  62  train_loss 0.0130  train_acc 0.9982  val_loss 0.0013  val_acc 1.0000  lr 3.13e-05
# epoch  63  train_loss 0.0119  train_acc 0.9965  val_loss 0.0010  val_acc 1.0000  lr 3.13e-05
# epoch  64  train_loss 0.0103  train_acc 0.9991  val_loss 0.0008  val_acc 1.0000  lr 3.13e-05
# epoch  65  train_loss 0.0246  train_acc 0.9956  val_loss 0.0009  val_acc 1.0000  lr 1.56e-05
# epoch  66  train_loss 0.0163  train_acc 0.9938  val_loss 0.0008  val_acc 1.0000  lr 1.56e-05
# epoch  67  train_loss 0.0196  train_acc 0.9938  val_loss 0.0014  val_acc 1.0000  lr 1.56e-05
# epoch  68  train_loss 0.0145  train_acc 0.9965  val_loss 0.0008  val_acc 1.0000  lr 1.56e-05
# epoch  69  train_loss 0.0151  train_acc 0.9973  val_loss 0.0007  val_acc 1.0000  lr 7.81e-06
# epoch  70  train_loss 0.0095  train_acc 0.9973  val_loss 0.0008  val_acc 1.0000  lr 7.81e-06
# epoch  71  train_loss 0.0165  train_acc 0.9956  val_loss 0.0008  val_acc 1.0000  lr 7.81e-06
# no val_loss improvement for 10 epochs, stopping early at epoch 71
# --- training: plus_dilated (params=432100) ---
# epoch   1  train_loss 0.8430  train_acc 0.6631  val_loss 1.0473  val_acc 0.6240  lr 1.00e-03
# epoch   2  train_loss 0.4770  train_acc 0.8267  val_loss 0.2780  val_acc 0.8926  lr 1.00e-03
# epoch   3  train_loss 0.3208  train_acc 0.8939  val_loss 0.1507  val_acc 0.9463  lr 1.00e-03
# epoch   4  train_loss 0.2864  train_acc 0.9010  val_loss 0.1552  val_acc 0.9587  lr 1.00e-03
# epoch   5  train_loss 0.2246  train_acc 0.9293  val_loss 0.2250  val_acc 0.9050  lr 1.00e-03
# epoch   6  train_loss 0.1975  train_acc 0.9434  val_loss 0.0790  val_acc 0.9628  lr 1.00e-03
# epoch   7  train_loss 0.2020  train_acc 0.9346  val_loss 0.4971  val_acc 0.7727  lr 1.00e-03
# epoch   8  train_loss 0.1745  train_acc 0.9372  val_loss 0.0838  val_acc 0.9793  lr 1.00e-03
# epoch   9  train_loss 0.1840  train_acc 0.9399  val_loss 0.1336  val_acc 0.9545  lr 1.00e-03
# epoch  10  train_loss 0.1616  train_acc 0.9523  val_loss 0.7500  val_acc 0.7934  lr 5.00e-04
# epoch  11  train_loss 0.1485  train_acc 0.9461  val_loss 0.0189  val_acc 1.0000  lr 5.00e-04
# epoch  12  train_loss 0.1004  train_acc 0.9752  val_loss 0.0767  val_acc 0.9752  lr 5.00e-04
# epoch  13  train_loss 0.1096  train_acc 0.9682  val_loss 0.0112  val_acc 1.0000  lr 5.00e-04
# epoch  14  train_loss 0.0762  train_acc 0.9814  val_loss 0.0066  val_acc 1.0000  lr 5.00e-04
# epoch  15  train_loss 0.0797  train_acc 0.9735  val_loss 0.0172  val_acc 1.0000  lr 5.00e-04
# epoch  16  train_loss 0.1015  train_acc 0.9726  val_loss 0.0164  val_acc 0.9959  lr 5.00e-04
# epoch  17  train_loss 0.0603  train_acc 0.9867  val_loss 0.0110  val_acc 1.0000  lr 5.00e-04
# epoch  18  train_loss 0.0543  train_acc 0.9885  val_loss 0.0115  val_acc 0.9959  lr 2.50e-04
# epoch  19  train_loss 0.0581  train_acc 0.9859  val_loss 0.0090  val_acc 1.0000  lr 2.50e-04
# epoch  20  train_loss 0.0512  train_acc 0.9859  val_loss 0.0062  val_acc 1.0000  lr 2.50e-04
# epoch  21  train_loss 0.0565  train_acc 0.9823  val_loss 0.0109  val_acc 1.0000  lr 2.50e-04
# epoch  22  train_loss 0.0451  train_acc 0.9876  val_loss 0.0171  val_acc 0.9959  lr 2.50e-04
# epoch  23  train_loss 0.0432  train_acc 0.9912  val_loss 0.0049  val_acc 1.0000  lr 2.50e-04
# epoch  24  train_loss 0.0305  train_acc 0.9938  val_loss 0.0039  val_acc 1.0000  lr 2.50e-04
# epoch  25  train_loss 0.0433  train_acc 0.9903  val_loss 0.0076  val_acc 1.0000  lr 2.50e-04
# epoch  26  train_loss 0.0571  train_acc 0.9885  val_loss 0.0136  val_acc 0.9959  lr 2.50e-04
# epoch  27  train_loss 0.0424  train_acc 0.9947  val_loss 0.0031  val_acc 1.0000  lr 2.50e-04
# epoch  28  train_loss 0.0436  train_acc 0.9894  val_loss 0.0020  val_acc 1.0000  lr 2.50e-04
# epoch  29  train_loss 0.0446  train_acc 0.9894  val_loss 0.0021  val_acc 1.0000  lr 2.50e-04
# epoch  30  train_loss 0.0434  train_acc 0.9876  val_loss 0.0031  val_acc 1.0000  lr 2.50e-04
# epoch  31  train_loss 0.0360  train_acc 0.9894  val_loss 0.0034  val_acc 1.0000  lr 2.50e-04
# epoch  32  train_loss 0.0365  train_acc 0.9885  val_loss 0.0026  val_acc 1.0000  lr 1.25e-04
# epoch  33  train_loss 0.0328  train_acc 0.9920  val_loss 0.0030  val_acc 1.0000  lr 1.25e-04
# epoch  34  train_loss 0.0450  train_acc 0.9929  val_loss 0.0019  val_acc 1.0000  lr 1.25e-04
# epoch  35  train_loss 0.0204  train_acc 0.9965  val_loss 0.0033  val_acc 1.0000  lr 1.25e-04
# epoch  36  train_loss 0.0382  train_acc 0.9867  val_loss 0.0017  val_acc 1.0000  lr 1.25e-04
# epoch  37  train_loss 0.0289  train_acc 0.9912  val_loss 0.0051  val_acc 1.0000  lr 1.25e-04
# epoch  38  train_loss 0.0253  train_acc 0.9947  val_loss 0.0022  val_acc 1.0000  lr 1.25e-04
# epoch  39  train_loss 0.0218  train_acc 0.9929  val_loss 0.0014  val_acc 1.0000  lr 1.25e-04
# epoch  40  train_loss 0.0260  train_acc 0.9965  val_loss 0.0010  val_acc 1.0000  lr 1.25e-04
# epoch  41  train_loss 0.0337  train_acc 0.9885  val_loss 0.0039  val_acc 1.0000  lr 1.25e-04
# epoch  42  train_loss 0.0305  train_acc 0.9920  val_loss 0.0015  val_acc 1.0000  lr 1.25e-04
# epoch  43  train_loss 0.0229  train_acc 0.9938  val_loss 0.0021  val_acc 1.0000  lr 1.25e-04
# epoch  44  train_loss 0.0314  train_acc 0.9920  val_loss 0.0020  val_acc 1.0000  lr 6.25e-05
# epoch  45  train_loss 0.0388  train_acc 0.9912  val_loss 0.0021  val_acc 1.0000  lr 6.25e-05
# epoch  46  train_loss 0.0297  train_acc 0.9912  val_loss 0.0038  val_acc 1.0000  lr 6.25e-05
# epoch  47  train_loss 0.0317  train_acc 0.9912  val_loss 0.0024  val_acc 1.0000  lr 6.25e-05
# epoch  48  train_loss 0.0194  train_acc 0.9956  val_loss 0.0015  val_acc 1.0000  lr 3.13e-05
# epoch  49  train_loss 0.0299  train_acc 0.9912  val_loss 0.0014  val_acc 1.0000  lr 3.13e-05
# epoch  50  train_loss 0.0248  train_acc 0.9929  val_loss 0.0028  val_acc 1.0000  lr 3.13e-05
# no val_loss improvement for 10 epochs, stopping early at epoch 50

# %% [markdown]
# ### Bring in the full CitrusNet baseline
#
# 416,036 params, best_epoch=30, best val_loss=0.00103, best val_acc=1.0000 - not retrained here, unaffected by the init fix.

# %%
full_df = pd.read_csv("history_baseline.csv")
if "epoch" not in full_df.columns:
    full_df.insert(0, "epoch", range(1, len(full_df) + 1))

all_histories = dict(histories_ordered)
all_histories["full_citrusnet"] = full_df

# %% [markdown]
# ### Summary table
#
# `epochs_to_reach_99pct` is the first epoch where val_acc >= 0.99, or "never". Rows kept in a fixed order rather than sorted, since the point here is the architecture toggles, not a speed ranking.

# %%
def summarize(name, df, use_ds, use_dil, n_params):
    best_idx = df["val_loss"].idxmin()
    reached = df[df["val_acc"] >= 0.99]
    epochs_to_99 = int(reached["epoch"].iloc[0]) if len(reached) > 0 else "never"

    return {
        "variant": name,
        "use_depthwise_separable": use_ds,
        "use_dilated": use_dil,
        "param_count": n_params,
        "epochs_run": int(df["epoch"].max()),
        "best_epoch": int(df.loc[best_idx, "epoch"]),
        "best_val_loss": float(df.loc[best_idx, "val_loss"]),
        "best_val_acc": float(df.loc[best_idx, "val_acc"]),
        "epochs_to_reach_99pct": epochs_to_99,
    }

rows = [
    summarize("standard_only", histories_ordered["standard_only"], False, False, param_counts["standard_only"]),
    summarize("plus_ds", histories_ordered["plus_ds"], True, False, param_counts["plus_ds"]),
    summarize("plus_dilated", histories_ordered["plus_dilated"], False, True, param_counts["plus_dilated"]),
    summarize("full_citrusnet", full_df, True, True, 416036),
]

summary_df = pd.DataFrame(rows)
summary_df
# Out:
#           variant  use_depthwise_separable  use_dilated  param_count  \
# 0   standard_only                    False        False       432100
# 1         plus_ds                     True        False       416036
# 2    plus_dilated                    False         True       432100
# 3  full_citrusnet                     True         True       416036
#
#    epochs_run  best_epoch  best_val_loss  best_val_acc  epochs_to_reach_99pct
# 0          49          39       0.002242           1.0                     11
# 1          71          61       0.000706           1.0                      8
# 2          50          40       0.000972           1.0                     11
# 3          40          30       0.001026           1.0                      4

# %% [markdown]
# ### Parameter-count check
#
# Dilation changes the receptive field, not the kernel size, so plus_dilated should match standard_only exactly. A depthwise-separable conv reaching 64 channels uses far fewer weights than a standard conv would, so plus_ds should come in well below standard_only. These come from the architecture, not the init, so they hold regardless of the init fix.

# %%
standard_params = param_counts["standard_only"]
ds_params = param_counts["plus_ds"]
dilated_params = param_counts["plus_dilated"]

dilated_matches_standard = dilated_params == standard_params
ds_is_fewer = ds_params < standard_params

print(f"standard_only params: {standard_params}")
print(f"plus_ds params:       {ds_params}")
print(f"plus_dilated params:  {dilated_params}")
print(f"plus_dilated == standard_only (dilation doesn't add weights): {dilated_matches_standard}")
print(f"plus_ds < standard_only (depthwise-separable uses fewer weights): {ds_is_fewer}")
# Out:
# standard_only params: 432100
# plus_ds params:       416036
# plus_dilated params:  432100
# plus_dilated == standard_only (dilation doesn't add weights): True
# plus_ds < standard_only (depthwise-separable uses fewer weights): True

# %% [markdown]
# ### Val loss, log scale

# %%
plt.figure(figsize=(8, 5))
for name, df in all_histories.items():
    plt.plot(df["epoch"], df["val_loss"], label=name)

plt.yscale("log")
plt.xlabel("epoch")
plt.ylabel("val_loss (log)")
plt.title("Validation loss by architecture variant")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Val accuracy, early-training view

# %%
plt.figure(figsize=(8, 5))
for name, df in all_histories.items():
    plt.plot(df["epoch"], df["val_acc"], label=name)

plt.ylim(0.5, 1.01)
plt.xlabel("epoch")
plt.ylabel("val_acc")
plt.title("Validation accuracy by architecture variant")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary

# %%
sort_key = summary_df["epochs_to_reach_99pct"].apply(lambda v: float("inf") if v == "never" else v)
fastest_row = summary_df.loc[sort_key.idxmin()]
lowest_loss_row = summary_df.loc[summary_df["best_val_loss"].idxmin()]

print(f"fastest to 99% val acc: {fastest_row['variant']} (epoch {fastest_row['epochs_to_reach_99pct']})")
print(f"lowest best val loss: {lowest_loss_row['variant']} ({lowest_loss_row['best_val_loss']:.6f})")
print(f"plus_dilated matches standard_only param count: {dilated_matches_standard}")
print(f"plus_ds has fewer params than standard_only: {ds_is_fewer}")
# Out:
# fastest to 99% val acc: full_citrusnet (epoch 4)
# lowest best val loss: plus_ds (0.000706)
# plus_dilated matches standard_only param count: True
# plus_ds has fewer params than standard_only: True
